# %% [markdown]
# # MeToo Analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from math import ceil, floor
import matplotlib.pyplot as plt
import seaborn as sns
import json
import matplotlib
from matplotlib import ticker
# %matplotlib inline

# %% [markdown]
# ### Preprocessing

# %%
data = pd.read_csv("../components/postprocess_data/artifacts/metoo_data.csv", sep = "\t", index_col = 0)
data["Date"] = pd.to_datetime(data["Date"])
data["Gender"] = data["Gender"].astype("category")
data["Account Type"] = data["Account Type"].astype("category")
data["Tweet Type"] = pd.Categorical(values = data["Tweet Type"], categories = ["share", "reply", "post"], ordered = True)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
def core_plot(data, ncols, pivot_col, fig_kwargs, plot_fun, core_plot_kwargs, supp_plot_kwargs):
    if fig_kwargs is None:
        fig_kwargs = {}
    if supp_plot_kwargs is None:
        supp_plot_kwargs = {}
    
    if pivot_col is not None:
        nrows = ceil(data[pivot_col].nunique() / ncols)
    else:
        nrows = 1
        ncols = 1
    fig, ax = plt.subplots(nrows, ncols, squeeze = False, constrained_layout = True, figsize = (6.4 * ncols, 4 * nrows), **fig_kwargs)
        
    if pivot_col is not None:
        for i, group in enumerate(data[pivot_col].dropna().unique()):
            plot_fun(data = data[data[pivot_col] == group], ax = ax[i // 2][i % 2], legend = (i == floor(data[pivot_col].nunique() / ncols)), **core_plot_kwargs, **supp_plot_kwargs)
            ax[i // 2][i % 2].set_title(group)
            ax[i // 2][i % 2].ticklabel_format(style = "plain", axis = "y")
        if data[pivot_col].nunique() < nrows * ncols:
            fig.delaxes(ax[nrows - 1][ncols - 1])
    else:
        sns.histplot(data = data, ax = ax[0][0], legend = True, **core_plot_kwargs, **supp_plot_kwargs)

# %%
def tweet_type_histogram(data, ncols = 2, pivot_col = None, fig_kwargs = None, plot_kwargs = None):
    core_plot(data, ncols, pivot_col, fig_kwargs, sns.histplot, {"x": "Date", "multiple": "stack", "bins": 50}, plot_kwargs)
    
def tweet_topic_lineplot(data, ncols = 2, pivot_col = None, fig_kwargs = None, plot_kwargs = None):
    core_plot(data, ncols, pivot_col, fig_kwargs, sns.lineplot, {"x": "Date", "y": "value"}, plot_kwargs)

# %%
def frequency_by_topic(data, groupings = []):
    query = (
        data[data["Tweet Type"] != "share"]
        .groupby([pd.Grouper(key = "Date", freq = "W")] + groupings)[[x for x in data.columns if "topic" in x]].mean()
        .melt(var_name = "topic", ignore_index = False)
        .reset_index()
        .groupby(["topic"] + groupings)
        .rolling(4, on = "Date", min_periods = 2).mean()
        .dropna()
        .reset_index()
    )
    
    return query

def tweet_volume(data, groupings = None):
    if groupings is not None:
        query = (
            data.groupby([pd.Grouper(key = "Date", freq = "W")] + groupings)["Tweet Type"].value_counts(normalize = True)
            .reset_index()
            .rename(columns = {"level_2": "Tweet Type", "Tweet Type": "value"})
            .groupby(["Tweet Type"] + groupings)
            .rolling(4, on = "Date").mean()
            .dropna()
            .reset_index()
        )
    else:
        query = (
            data.groupby(pd.Grouper(key = "Date", freq = "W"))["Tweet Type"].value_counts(normalize = True)
            .reset_index()
            .rename(columns = {"level_1": "Tweet Type", "Tweet Type": "value"})
            .groupby("Tweet Type")
            .rolling(4, on = "Date").mean()
            .dropna()
            .reset_index()
        )
    
    return query

# %% [markdown]
# #### Aggregate Tweet Volume

# %%
tweet_type_histogram(data, plot_kwargs = {"hue": "Tweet Type"})

# %%
query = tweet_volume(data)
sns.lineplot(data = query, x = "Date", y = "value", hue = "Tweet Type")
# Out:
# <AxesSubplot:>

# %% [markdown]
# As evidenced above, the majority of the tweets in the dataset occur in the months after Alyssa Milano [popularized the #MeToo hashtag](https://twitter.com/alyssa_milano/status/919659438700670976) in late 2017. There was also a significant spike around October of the following year surrounding the nomination of Brett Kavanaugh to the Supreme Court of the United States.

# %% [markdown]
# #### Tweet Volume by Gender

# %%
tweet_type_histogram(data, pivot_col = "Gender", fig_kwargs = {"sharey": True}, plot_kwargs = {"hue": "Tweet Type"})

# %%
query = tweet_volume(data, ["Gender"])
tweet_topic_lineplot(query, pivot_col = "Tweet Type", plot_kwargs = {"hue": "Gender"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27828/1609352251.py in <module>
#       1 query = tweet_volume(data, ["Gender"])
# ----> 2 tweet_topic_lineplot(query, pivot_col = "Tweet Type", plot_kwargs = {"hue": "Gender"})
#
# ~\AppData\Local\Temp/ipykernel_27828/936882819.py in tweet_topic_lineplot(data, ncols, pivot_col, fig_kwargs, plot_kwargs)
#       3
#       4 def tweet_topic_lineplot(data, ncols = 2, pivot_col = None, fig_kwargs = None, plot_kwargs = None):
# ----> 5     core_plot(data, ncols, pivot_col, fig_kwargs, sns.lineplot, {"x": "Date", "y": "value"}, plot_kwargs)
#
# ~\AppData\Local\Temp/ipykernel_27828/2282770127.py in core_plot(data, ncols, pivot_col, fig_kwargs, plot_fun, core_plot_kwargs, supp_plot_kwargs)
#      10         nrows = 1
#      11         ncols = 1
# ---> 12     fig, ax = plt.subplots(nrows, ncols, squeeze = False, constrained_layout = True, figsize = (6.4 * ncols, 4 * nrows), **fig_kwargs)
#      13
#      14     if pivot_col is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1438     """
#    1439     fig = figure(**fig_kw)
# -> 1440     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1441                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1442                        gridspec_kw=gridspec_kw)
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#     908         if gridspec_kw is None:
#     909             gridspec_kw = {}
# --> 910         gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     911         axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     912                           subplot_kw=subplot_kw)
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_gridspec(self, nrows, ncols, **kwargs)
#    1406
#    1407         _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1408         gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1409         self._gridspecs.append(gs)
#    1410         return gs
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in __init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     395         self.figure = figure
#     396
# --> 397         super().__init__(nrows, ncols,
#     398                          width_ratios=width_ratios,
#     399                          height_ratios=height_ratios)
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in __init__(self, nrows, ncols, height_ratios, width_ratios)
#      47         """
#      48         if not isinstance(nrows, Integral) or nrows <= 0:
# ---> 49             raise ValueError(
#      50                 f"Number of rows must be a positive integer, not {nrows}")
#      51         if not isinstance(ncols, Integral) or ncols <= 0:
#
# ValueError: Number of rows must be a positive integer, not 0

# %% [markdown]
# Based on these charts, it appears that women engaged more frequently with the #MeToo movement than men. In total, women accounted for 3.5M total engagements in the dataset vs. 3M for males.

# %% [markdown]
# #### Engagement by Gender

# %%
fig, ax = plt.subplots()
query = data.groupby("Gender")[["Tweet Type"]].value_counts(normalize = True)
query.name = "% of Total"
sns.barplot(data = query.reset_index(), x = "Tweet Type", y = "% of Total", hue = "Gender", ax = ax)
ax.yaxis.set_major_formatter(ticker.PercentFormatter(1))

# %% [markdown]
# A reasonable a priori hypothesis might have been that there are significant differences in engagement patterns for male and female users; based on these charts, however, the patterns are quite similar across the two.

# %% [markdown]
# #### Engagement Distribution by Account Type

# %%
tweet_type_histogram(data, pivot_col = "Account Type", plot_kwargs = {"hue": "Tweet Type"})

# %%
query = tweet_volume(data, ["Account Type"])
tweet_topic_lineplot(query, pivot_col = "Tweet Type", plot_kwargs = {"hue": "Account Type"})

# %% [markdown]
# Engagement behavior with the #MeToo movement certainly differs by account type, with organizations posting far more often (and retweeting much less so) than individual users.

# %% [markdown]
# #### Interaction Frequency by Account Type

# %%
fig, ax = plt.subplots()
query = data.groupby("Account Type")[["Tweet Type"]].value_counts(normalize = True)
query.name = "% of Total"
sns.barplot(data = query.reset_index(), x = "Tweet Type", y = "% of Total", hue = "Account Type", ax = ax)
ax.yaxis.set_major_formatter(ticker.PercentFormatter(1))

# %% [markdown]
# ### Influencers vs. Core Users
#
# Tangential to the above observation that engagement behavior differs by account type is the hypothesis that "influencers" (i.e. users with high following) may engage differently than "core users" (i.e. users with low following).
#
# In order to test this hypothesis, we separate influencers from core users using a simple heuristic (here, individual accounts with greater than 20,000 following).

# %% [markdown]
# These charts bear out a similar disparity in user behavior for core vs. influencer users. The latter engage with the movement much more organically (i.e. by creating their own posts), while the former engage primary through retweeting (although replying also seems to be a more common mode here as well).

# %% [markdown]
# ### Prevalent Topics Over Time

# %%
query = frequency_by_topic(data)
tweet_topic_lineplot(query, pivot_col = "topic")

# %%
query
# Out:
#         topic  level_1       Date     value
# 0     topic_1        0 2017-10-15  0.025411
# 1     topic_1        1 2017-10-22  0.031313
# 2     topic_1        2 2017-10-29  0.032194
# 3     topic_1        3 2017-11-05  0.034167
# 4     topic_1        4 2017-11-12  0.036208
# ...       ...      ...        ...       ...
# 2755  topic_9     1237 2020-05-03  0.034572
# 2756  topic_9     1238 2020-05-10  0.039007
# 2757  topic_9     1239 2020-05-17  0.038611
# 2758  topic_9     1240 2020-05-24  0.036113
# 2759  topic_9     1241 2020-05-31  0.034452
#
# [2760 rows x 4 columns]

# %%
query = frequency_by_topic(data[~data["Account Type"].isin(["business", "news"])], groupings = ["Account Type"])
tweet_topic_lineplot(query, pivot_col = "topic", plot_kwargs = {"hue": "Account Type"})

# %%
query = frequency_by_topic(data, groupings = ["Gender"])
tweet_topic_lineplot(query, pivot_col = "topic", plot_kwargs = {"hue": "Gender"})

# %%
query = data.groupby("Account Type")["Account Type_orig"].value_counts(normalize = True).unstack(level = 1)
sns.heatmap(data = query, annot = True)
# Out:
# <AxesSubplot:xlabel='Account Type_orig', ylabel='Account Type'>

# %%
def calc_pmi(data, x, y):
    return np.log(data[data[

# %%
data["Gender"].value_counts(normalize = True)
# Out:
# female    0.539805
# male      0.460195
# Name: Gender, dtype: float64

# %%
data[data["Gender"] == "male"]["

# %%
query = data.groupby("Account Type_orig")["Account Type"].value_counts(normalize = True).unstack(level = 1)
sns.heatmap(data = query, annot = True)
# Out:
# <AxesSubplot:ylabel='Account Type_orig'>

# %%
data.columns
# Out:
# Index(['Date', 'Page Type', 'Author', 'Full Name', 'Full Text', 'Hashtags',
#        'Impact', 'Impressions', 'Tweet Type', 'Thread Author',
#        'Twitter Followers', 'Twitter Following', 'Twitter Tweets',
#        'Twitter Reply Count', 'Twitter Verified', 'Twitter Retweets',
#        'Reach (new)', 'Region', 'topic_1', 'topic_2', 'topic_3', 'topic_4',
#        'topic_5', 'topic_6', 'topic_7', 'topic_8', 'topic_9', 'topic_10',
#        'topic_11', 'topic_12', 'topic_13', 'topic_14', 'topic_15', 'topic_16',
#        'topic_17', 'topic_18', 'topic_19', 'topic_20', 'screen', 'Gender',
#        'Account Type', 'followers_count', 'screen_orig', 'Gender_orig',
#        'Account Type_orig', 'followers_count_orig'],
#       dtype='object')

# %%
test = data[data["screen"].str.lower() == "alyssa_milano"].sort_values(by = "Date")

# %%
data[data["Date"] < "2017-10-15"].shape

# %%
data[data["Account Type"] == "organisational"]["Author"].value_counts().nlargest(20)
# Out:
# LeadingWPassion    12362
# metoozoo            6587
# XWIGS               6305
# LoriHandrahan2      5948
# AroundOMedia        3638
# ggbrokensilence     3508
# ReneNowb            3161
# RestlessNews        2836
# sexualassaulte1     2006
# rockviewtees        1979
# jenirwinauthor      1611
# INSSAOnline         1607
# GrassrootsDNC       1427
# boyfacemedia        1009
# MainChannel_         986
# TurtleWoman777       890
# NewAppleAwards       880
# politiciandirec      858
# agitpopworld         825
# YourAnonRevolt       751
# Name: Author, dtype: int64

# %%
data[data["Author"] == "LeadingWPassion"]
# Out:
#                        Date Page Type           Author  \
# 254826  2018-10-05 23:53:13   twitter  LeadingWPassion
# 256350  2018-10-05 23:25:24   twitter  LeadingWPassion
# 257985  2018-10-05 22:56:22   twitter  LeadingWPassion
# 259343  2018-10-05 22:28:14   twitter  LeadingWPassion
# 260927  2018-10-05 21:57:20   twitter  LeadingWPassion
# ...                     ...       ...              ...
# 7124417 2018-07-29 02:17:16   twitter  LeadingWPassion
# 7124503 2018-07-29 01:49:14   twitter  LeadingWPassion
# 7124630 2018-07-29 01:21:23   twitter  LeadingWPassion
# 7124781 2018-07-29 00:53:16   twitter  LeadingWPassion
# 7124939 2018-07-29 00:21:17   twitter  LeadingWPassion
#
#                                      Full Name  \
# 254826   LeadingWPassion (LeadingWithPassion™)
# 256350   LeadingWPassion (LeadingWithPassion™)
# 257985   LeadingWPassion (LeadingWithPassion™)
# 259343   LeadingWPassion (LeadingWithPassion™)
# 260927   LeadingWPassion (LeadingWithPassion™)
# ...                                        ...
# 7124417  LeadingWPassion (LeadingWithPassion™)
# 7124503  LeadingWPassion (LeadingWithPassion™)
# 7124630  LeadingWPassion (LeadingWithPassion™)
# 7124781  LeadingWPassion (LeadingWithPassion™)
# 7124939  LeadingWPassion (LeadingWithPassion™)
#
#                                                  Full Text  \
# 254826   tries instead reacting learn respond empower g...
# 256350   woman difference rock world genderequality fem...
# 257985   domestic violence end domestic violence share ...
# 259343   benefit soft skills woman men benefit learning...
# 260927   types domestic violence learn genderequality f...
# ...                                                    ...
# 7124417    men afraid strong women genderequality feminism
# 7124503  possible estimated people worldwide exploited ...
# 7124630  stop dwelling past charge life today genderequ...
# 7124781  femicide help prevent learn genderequality fem...
# 7124939                 wake today genderequality feminism
#
#                                    Hashtags  Impact  Impressions Tweet Type  \
# 254826   #genderequality, #feminism, #metoo    47.7      62169.0       post
# 256350   #genderequality, #feminism, #metoo    47.7      62169.0       post
# 257985   #genderequality, #feminism, #metoo    47.7      62178.0       post
# 259343   #genderequality, #feminism, #metoo    47.7      62176.0       post
# 260927   #genderequality, #feminism, #metoo    47.7      62176.0       post
# ...                                     ...     ...          ...        ...
# 7124417  #genderequality, #feminism, #metoo    48.0      63759.0       post
# 7124503  #genderequality, #feminism, #metoo    48.0      63756.0       post
# 7124630  #genderequality, #feminism, #metoo    48.0      63753.0       post
# 7124781  #genderequality, #feminism, #metoo    48.0      63754.0       post
# 7124939  #genderequality, #feminism, #metoo    51.2      75266.0       post
#
#         Thread Author  ...  topic_19  topic_20           screen  Gender  \
# 254826            NaN  ...       0.0       0.0  LeadingWPassion  female
# 256350            NaN  ...       0.0       0.0  LeadingWPassion  female
# 257985            NaN  ...       0.0       0.0  LeadingWPassion  female
# 259343            NaN  ...       0.0       0.0  LeadingWPassion  female
# 260927            NaN  ...       0.0       0.0  LeadingWPassion  female
# ...               ...  ...       ...       ...              ...     ...
# 7124417           NaN  ...       NaN       NaN  LeadingWPassion  female
# 7124503           NaN  ...       NaN       NaN  LeadingWPassion  female
# 7124630           NaN  ...       NaN       NaN  LeadingWPassion  female
# 7124781           NaN  ...       NaN       NaN  LeadingWPassion  female
# 7124939           NaN  ...       NaN       NaN  LeadingWPassion  female
#
#            Account Type  followers_count  screen_orig Gender_orig  \
# 254826   organisational          50474.0          NaN         NaN
# 256350   organisational          50474.0          NaN         NaN
# 257985   organisational          50474.0          NaN         NaN
# 259343   organisational          50474.0          NaN         NaN
# 260927   organisational          50474.0          NaN         NaN
# ...                 ...              ...          ...         ...
# 7124417  organisational          50474.0          NaN         NaN
# 7124503  organisational          50474.0          NaN         NaN
# 7124630  organisational          50474.0          NaN         NaN
# 7124781  organisational          50474.0          NaN         NaN
# 7124939  organisational          50474.0          NaN         NaN
#
#          Account Type_orig  followers_count_orig
# 254826                 NaN                   NaN
# 256350                 NaN                   NaN
# 257985                 NaN                   NaN
# 259343                 NaN                   NaN
# 260927                 NaN                   NaN
# ...                    ...                   ...
# 7124417                NaN                   NaN
# 7124503                NaN                   NaN
# 7124630                NaN                   NaN
# 7124781                NaN                   NaN
# 7124939                NaN                   NaN
#
# [12362 rows x 46 columns]
